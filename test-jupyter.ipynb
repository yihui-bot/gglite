# %%
library(gglite)
g2(mtcars, x = 'mpg', y = 'hp') |> mark_point()

# %%
# Second chart to verify multiple charts work
g2(mtcars, x = 'cyl') |> mark_interval()
